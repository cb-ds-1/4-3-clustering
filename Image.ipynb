# %%
#from https://towardsdatascience.com/image-compression-using-k-means-clustering-aa0c91bb0eeb

from skimage import io
from sklearn.cluster import KMeans
import numpy as np

#Read the image
image = io.imread('/content/drive/MyDrive/16473748_10155026500977769_5216571254011182883_n.jpg')
io.imshow(image)
io.show()

#Dimension of the original image
rows = image.shape[0]
cols = image.shape[1]

#Flatten the image
image = image.reshape(rows * cols, 3)

#Implement k-means clustering to form k clusters
kmeans = KMeans(n_clusters = 64)
kmeans.fit(image)

#Replace each pixel value with its nearby centroid
compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_64.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=32)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_32.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_8.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=128)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_128.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=256)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_256.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_4.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(image)

compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

#Reshape the image to original dimension
compressed_image = compressed_image.reshape(rows, cols, 3)

#Save and display output image
io.imsave('compressed_image_2.png', compressed_image)
io.imshow(compressed_image)
io.show()

# %%
#From the above code, the first picture that we see is the original. The rest of the pictures were created using different cluster
#sizes (2, 4, 8, 32, 64, 128, and 256). From what we can see, the picture gets more distorted as the number of clusters decrease.
#Based on the results of the pictures, it would seem that 64 clusters would be the best choice because there is no visible change
#compared to the original picture.

#As the number of clusters decreased, the images lost color and became more saturated. When there were 8 clusters, we can't tell that
#the blue on the right side is a towel. At 4 clusters, there was a drastic loss in color to the point that even the dog's colors are
#no longer distinguishable. At 2 clusters, we might be able to deduce that there is a dog, but we can't figure out where he is or
#what is surrounding him.

#As the number of clusters increased, we didn't really see any major difference between the pictures from 32+ clusters. Had I put
#a higher number of clusters than 256, it's possible that there would have been a lot more overlap between the cluster colors. Therefore,
#the images might become oversaturated due to too many pixels. As we increased the number of clusters, however, it took more time for
#the code to run. For that reason, it made no sense to use more than 256, which already took a few minutes to load.
